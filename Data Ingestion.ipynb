# %%
from censaurus.dataset import Dataset
import pandas as pd

# %%
example_variables = ['NAICS2017', 'NAICS2017_LABEL', 'SEX', 'SEX_LABEL', 'ETH_GROUP', 'ETH_GROUP_LABEL', 'RACE_GROUP', 'RACE_GROUP_LABEL', 'VET_GROUP', 'VET_GROUP_LABEL', 'EMPSZFI', 'EMPSZFI_LABEL', 'YEAR', 'FIRMPDEMP', 'FIRMPDEMP_F', 'RCPPDEMP', 'RCPPDEMP_F', 'EMP', 'EMP_F', 'PAYANN', 'PAYANN_F', 'FIRMPDEMP_S', 'FIRMPDEMP_S_F', 'RCPPDEMP_S', 'RCPPDEMP_S_F', 'EMP_S', 'EMP_S_F', 'PAYANN_S', 'PAYANN_S_F']

# %%
d = Dataset(url_extension='2021/abscs', map_service='tigerWMS_Current')

# %%
data = d.us(variables=example_variables)

# %%
#print(data)
# Out:
#       NAICS2017            NAICS2017_LABEL  SEX SEX_LABEL ETH_GROUP  \
# 0            00      Total for all sectors  001     Total       001
# 1            00      Total for all sectors  001     Total       001
# 2            00      Total for all sectors  001     Total       001
# 3            00      Total for all sectors  001     Total       001
# 4            00      Total for all sectors  001     Total       001
# ...         ...                        ...  ...       ...       ...
# 55865        99  Industries not classified  001     Total       001
# 55866        99  Industries not classified  001     Total       001
# 55867        99  Industries not classified  001     Total       001
# 55868        99  Industries not classified  001     Total       001
# 55869        99  Industries not classified  001     Total       001
#
#       ETH_GROUP_LABEL RACE_GROUP              RACE_GROUP_LABEL VET_GROUP  \
# 0               Total         00                         Total       001
# ...

# %%
df = pd.DataFrame(data)

# %%
df.head(10)
# Out:
#   NAICS2017        NAICS2017_LABEL  SEX SEX_LABEL ETH_GROUP ETH_GROUP_LABEL  \
# 0        00  Total for all sectors  001     Total       001           Total
# 1        00  Total for all sectors  001     Total       001           Total
# 2        00  Total for all sectors  001     Total       001           Total
# 3        00  Total for all sectors  001     Total       001           Total
# 4        00  Total for all sectors  001     Total       001           Total
# 5        00  Total for all sectors  001     Total       001           Total
# 6        00  Total for all sectors  001     Total       001           Total
# 7        00  Total for all sectors  001     Total       001           Total
# 8        00  Total for all sectors  001     Total       001           Total
# 9        00  Total for all sectors  001     Total       001           Total
#
#   RACE_GROUP RACE_GROUP_LABEL VET_GROUP VET_GROUP_LABEL  ... FIRMPDEMP_S_F  \
# ...
